# %% [markdown]
# # Customer segmentation
# ### Jimmy Azar

# %% [markdown]
# ## Introduction
#
# We'll explore customer segmentation by statistical methods. In particular, we'll use k-means clustering and select the optimal number of clusters by silhouette information. We will then identify the most valued segment and its properties.

# %% [markdown]
# ## Read-in data
#
# Our data consists of real purchases made between 01.12.2010 and 09.12.2011 at a retail company that sells mostly online gift items. The data is provided in the file "invoices.csv". Read the file using **pd.read_csv()** and inspect the data. How many observations and variables are there?

# %%
import pandas as pd
import numpy as np

path_to_file = './data/invoices.csv'
data = pd.read_csv(path_to_file)

data.head()
data.shape;

# %% [markdown]
# ## Data preparation
#
# Inspect the "quantity" field, and check if there are any quantities that are not positive! Show the first 6 observations that have negative quantities. Negative values signify that the order was canceled, and these transactions can be ignored for our purpose. Create a new data frame by ignoring these observations and keeping only those with `quantity > 0`.
#
# Next, inspect the field "customer_id". Are there any missing values yielding "NaN" (not a number)? (hint: **isna()** or **isnull()**). How many are these? Remove any observation containing NaN values by applying **dropna()** on the data frame. What is the size of the dataset now?
#
# To interpret "invoice_date" as an actual date, use pandas' **to_datetime()** and overwrite the corresponding column:

# %%
#data preparation
data.loc[data['quantity']<0].head(6) 
df = data.loc[data['quantity']>0]
df.loc[df['customer_id'].isna()] #or .isnull()
df = df.dropna(subset=['customer_id']) 
df.shape;

# %%
df['invoice_date'] = pd.to_datetime(df['invoice_date'])

# %% [markdown]
# The earliest date is 2010-12-01 and the most recent is 2011-12-09. Verify this using **min()** and **max()**. The data therefore spans around a year. Let us remove data from the last (incomplete) month of December 2011. Note that datetime conversion stores dates as numeric values, and so these can be compared, added, or subtracted, etc. To remove data from the last month, remove any observation with an invoice date that is literally "less than" '2011-12-01'. What are the dimensions of your dataset now?

# %%
df['invoice_date'] = pd.to_datetime(df['invoice_date'])
df['invoice_date'].min()
df['invoice_date'].max()

df = df.loc[df['invoice_date']<'2011-12-01']
df.shape 

df['quantity'].value_counts(); #a table count

# %% [markdown]
# ## Feature extraction
#
# We are interested in the revenue made for each type of item purchased; therefore, add a column named "sales" to your data frame `df` which should consist of the *quantity* value multiplied by the *unit price* value for each observation (row).
#
# For each unique customer ID, we will derive three features: total sales, order count, and average sales. Total sales is the sum of all sales for a given customer. Order count is the total number of unique orders made by a customer and is measured using unique invoice dates. Average sales is the total sales for a given customer divided by the order count for that customer. Create a data frame "df_customers" with "customer_id" as row index and with columns "total_sales", "order_count", and "avg_sales". Note that you may build this data frame without `for` loops by using pandas' **groupby()** followed by functions you wish to apply. What are the dimensions of the resulting data frame?
#
# The features we have derived so far are a good start, however, their scales differ largely. Moreover, most customers will have relatively low sales and order count and can expect to form one dense cluster, whereas a few outliers with large feature values will form their own small clusters. To mitigate this problem, we will instead use rank data of the original features (this bears resemblance in statistics to non-parametric Kruskal-Wallis ANOVA). Create a new data frame "df_rank" similar to "df_customers" but where each feature value is replaced by its corresponding rank within its own column. Ranks proceed in increasing order with the smallest value having a rank of 1. Hint: use **rank(method='first')**.
#
# Although using rank data ensures feature scales are comparable, nonetheless, we will normalize the data to have zero mean and unit variance. Copy "df_rank" into a new data frame, "df_norm", and normalize the features of "df_norm" by removing the mean and dividing by the standard deviation or using the function **scale()** from **sklearn.preprocessing** (make sure you place the result back in a data frame with 3 columns and customer_id as index). Finally, check that the resulting dataset is of zero mean and unit variance using **df_norm.describe().loc[['mean','std']]**. We are now ready to segment our normalized dataset using clustering.

# %%
#feature extraction
df['sales'] = df['quantity'] * df['unit_price']

df_customers = df.groupby(['customer_id']).aggregate({'sales': 'sum', 'invoice_date': 'nunique'})
df_customers = df_customers.rename(columns={'sales':'total_sales', 'invoice_date':'order_count'})
df_customers['avg_sales'] = df_customers['total_sales']/df_customers['order_count']

#alternatively:
#df_customers['total_sales'] = df.groupby(['customer_id'])['sales'].sum() 
#df_customers['order_count'] = df.groupby(['customer_id'])['invoice_date'].apply(lambda x: len(x.unique()))
#df_customers['avg_sales'] = df_customers['total_sales']/df_customers['order_count']

df_customers.describe()
df_customers.shape

df_rank = df_customers.rank(method='first') #default is average

from sklearn.preprocessing import scale

df_norm = pd.DataFrame(scale(df_rank), index=df_rank.index, columns=df_rank.columns) 

#alternatively: 
#df_norm = (df_rank - df_rank.mean())/df_rank.std() #note: ddof for std is different between numpy and pandas

df_norm.describe().loc[['mean','std']];

# %% [markdown]
# ## Customer segmentation by k-means clustering
#
# We are interested in clustering our data into at least 4 clusters. Call the function **KMeans()** from **sklearn.cluster** to perform the segmentation. The first argument `n_clusters` specifies the number of clusters required, the second argument `max_iter` specifies the maximum number of iterations allowed, and the third argument `n_init` indicates the number of repetitions with random initialization. The four cluster centers can be accessed using attribute `model.cluster_centers_` once the model has been fitted to the data, whereas cluster labels are found in `model.labels_`. The last part of the code summarizes the count (or size) of each cluster.

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=4, max_iter=100, n_init=10).fit(df_norm)
model.labels_
model.cluster_centers_ #each row is a cluster center

#label count as dict
values, counts = np.unique(model.labels_, return_counts=True) #tuple of arrays
dict(zip(values, counts))

#or as ndarray
np.array(np.unique(model.labels_, return_counts=True))  

#or as Series
df_customers['label'] = model.labels_
df_customers.groupby(['label'])['order_count'].count();

# %% [markdown]
# For each cluster center representing a segment, we can compute the average feature values. Find the profile of each cluster in terms of actual (not normalized) total sales, order count, and average sales of its corresponding center using the line below.

# %%
df_customers['label'] = model.labels_
df_customers.groupby(['label']).mean();

# %% [markdown]
# ### Optimal number of clusters by silhouette
#
# So far we have selected the number of clusters, $k=4$, arbitrarily. Instead, we may optimize the selection of $k$ over a range of values. The criterion we will use is the silhouette coefficient which lies in $[-1,1]$. We automatically select $k$ which maximizes this coefficient. Since we are interested in having at least 4 clusters, we choose a range for $k$ from 4 to 10 clusters to test out. Once the data has been clustered, a silhouette value, $s(i)$ for a given object $i$ is given by:
#
# $$s(i) := \dfrac{b(i) - a(i)}{max(a(i),b(i))}$$
#
# $a(i)$ is the average dissimilarity between object $i$ and all other points (excluding $i$) which belong to the cluster that $i$ belongs to. That is, $a(i) := \dfrac{1}{|C_i|-1}\sum_{j \in C_i, i\neq j} d(i,j)$. All dissimilarities can be computed by constructing the distance matrix $d(i,j)$. We divide by $|C_i|-1$ because we do not include the distance $d(i,i)$ in the sum. In case object $i$ is the only object in its cluster, then we set $s(i) := 0$. The variable $b(i)$ is the minimum among all average dissimilarities measured between object $i$ and the instances of another cluster which $i$ does not belong to. That is, $b(i) := \underset{C}{\operatorname{min}} d(i,C)$ where $d(i,C)$ is the average dissimilarity of $i$ to all instances in cluster $C$ which $i$ does not belong to. The cluster with the smallest $b(i)$ is the "neighboring cluster" of $i$: it is the next best fit cluster for point $i$.
#
# $s(i)$ close to 1 means that $a(i) << b(i)$, and so $i$ is closer or more "similar" to its own cluster than its neighboring cluster; thus $i$ is well-labeled. If $s(i)$ is close to $-1$, then $a(i) >> b(i)$, and so $i$ is better off belonging to its neighboring cluster and is thus poorly labeled. If $s(i) = 0$, then $i$ is equally likely to fall into either its own cluster or its neighboring cluster, so $i$ lies between two clusters.
#
# The silhouette value $s(i)$ applies to each clustered observation. The silhouette coefficient to assess the overall clustering is taken to be the mean of all silhouette values $S := \dfrac{1}{n}\sum_i s(i)$. We select $k$ that maximizes this coefficient.
#
# Scikit-learn provides **silhouette_score()** (from **sklearn.metrics**) for computing $S$. The function takes as arguments the data and the cluster labels returned by some clustering model like k-means. The method computes all distances and silhouette values internally and returns the overall silhouette coefficient or score.
#
# Run a `for` loop over $k$ from 4 to 10 clusters, where in each iteration: (i) call **KMeans()** to cluster the data in "df_norm" using $k$ clusters and obtain the labels, and (ii) compute the silhouette coefficient. Either print the silhouette coefficient for each $k$ within the `for` loop (hint: **print()**, f-string **f'...'**, or **str()**, etc.), or store these values and print them outside the `for` loop. Based, on the results, which is the optimal number of clusters to choose?
#
# Now that the optimal value for $k$ has been identified, re-run k-means using this value. As we've done previously, find the profile of each cluster in terms of actual (not normalized) total sales, order count, and average sales of its corresponding center. Identify which cluster (label) represents our most-valued customers, e.g. has the highest average sales (e.g. through **argmax()** or **idxmax()**).
#
# Add a column to the data frame "df_norm" called "label" indicating the cluster label for each observation.

# %%
#optimal number of clusters by silhouette
from sklearn.metrics import silhouette_score

#store nothing
k_optimal, highest_score = 0, 0
for k in range(4,11):
    labels = KMeans(n_clusters=k, max_iter = 100, n_init=10).fit_predict(df_norm)
    score = silhouette_score(df_norm, labels)
    #print(f'For k={k}, silhouette coefficient = {score}')
    
    if highest_score < score:
        highest_score = score
        k_optimal = k

k_optimal

'''
#alternatively: dict
scores = {}
for i in range(4,11):
    model = KMeans(n_clusters = i, max_iter = 100,n_init=10).fit(df_norm)
    scores[i] = silhouette_score(df_norm, model.labels_)

k_optimal = max(scores, key=scores.get)
k_optimal

#alternatively: list
k_values, scores = range(4,11), []
for k in k_values:
    model = KMeans(n_clusters=k, max_iter = 100, n_init=10).fit(df_norm)
    score = silhouette_score(df_norm, model.labels_)
    scores.append(score)    

k_optimal = k_values[np.argmax(scores)] #or k_values[scores.index(max(scores))]
k_optimal
'''

model = KMeans(n_clusters=k_optimal, max_iter = 100, n_init=10).fit(df_norm)

df_customers['label'] = model.labels_ #overwrite labels with those of final model

high_value_label = df_customers.groupby('label').mean()['avg_sales'].argmax()

df_norm['label'] = model.labels_

# %% [markdown]
# ## Identify high-valued segment
#
# Using the identified cluster label corresponding to high-valued customers, provide a summary of the (non-normalized) features corresponding to this segment (hint: **describe()**).
#
# Also, list the customer IDs of all high-valued customers belonging to this cluster. Save these values in variable `vip`. Create a data frame "df_vip" consisting of data from the original data frame "df" but including only observations (rows) for which "customer_id" belongs to the `vip` list (hint: **isin()**)
#
# Finally, we are interested in displaying the item descriptions and their count, that these customers have bought. To that purpose, find the count of each description (e.g. using **groupby()** over data frame "df_vip"). The result should be a data frame called "items" with index name "description" and column name "count".
#
# Re-order the data frame items to display the descriptions from those with highest count at the top, and show the six most frequent items bought by the high-valued customer segment.

# %%
high_valued_customers = df_customers.loc[df_customers['label'] == high_value_label]
high_valued_customers.describe()

vip = np.array(high_valued_customers.index) #.tolist()

df_vip = df.loc[df['customer_id'].isin(vip)]

items = df_vip.groupby('description').aggregate({'description': 'count'})
items = items.rename(columns= {'description': 'count'})

items = items.sort_values(by=["count"], ascending = False) #.sort_values() for DataFrames 
items.head(6);
